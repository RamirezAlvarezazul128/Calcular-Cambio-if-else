# %% [markdown]
# <a href="https://colab.research.google.com/github/RamirezAlvarezazul128/Calcular-Cambio-if-else/blob/main/El_profe_Act_12_Cambio_Ramirez_Anne_0441.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ramirez Anne NL = 44 Fecha 26/mar/2026
# ### Calulando el cambio usando if else
# ### mirar diagrama de flujo
# <img src="https://raw.githubusercontent.com/RamirezAlvarezazul128/Calcular-Cambio-if-else/refs/heads/main/cambio%202.jfif" width="300" height="300" alt="Imagen de ejemplo">
#
# ## las variables
# 1. Cp --> Costo del producto
# 2. CD --> Cantidad de dinero
# 3. Cambio
#
# ## Formulas
# $Cambio = CD - CP$
#
# ## Diagrama de flujo LucidChart
# <img src="https://raw.githubusercontent.com/RamirezAlvarezazul128/Calcular-Cambio-if-else/refs/heads/main/DF%20if%20else%20cambio%202.png" width="400" height="500" alt="Imagen de ejemplo">

# %%
# para cuando es verdadero (si)
# Calculando el cambio usando if else
# datos de entrada CD, CP
# mostrar Cambio si es falso
# si es verdadero mostrar NO alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
  Cambio = CD - CP
  print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado por Ramirez Anne NL = 44")
# Out:
# Ingrese el costo del producto: 500
# Ingrese la cantidad de dinero: 400
# No alcanza
# Fin del programa
# Programa realizado por Ramirez Anne NL = 44

# %%
# para cuando es falso (no)
# Calculando el cambio usando if else
# datos de entrada CD, CP
# mostrar Cambio si es falso
# si es verdadero mostrar NO alcanza
CP = float(input("Ingrese el costo del producto: "))
CD = float(input("Ingrese la cantidad de dinero: "))
if CP > CD:
    print("No alcanza")
else:
  Cambio = CD - CP
  print("El cambio es: ", Cambio)
print("Fin del programa")
print("Programa realizado por Ramirez Anne NL = 44")
# Out:
# Ingrese el costo del producto: 250
# Ingrese la cantidad de dinero: 300
# El cambio es:  50.0
# Fin del programa
# Programa realizado por Ramirez Anne NL = 44

# %% [markdown]
# # Relacion entre codigo y diagrama de flujo
# <img src="https://raw.githubusercontent.com/RamirezAlvarezazul128/Calcular-Cambio-if-else/refs/heads/main/tldraw%20cambio%20if%20else%202.png" width="800" height="500" alt="Imagen de ejemplo">
